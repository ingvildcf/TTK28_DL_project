# %% [markdown]
# # Music Genre Classification

# %%
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
from tqdm import tqdm
import os

import librosa.display
import deeplake

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Load dataset

# %%
#ds = deeplake.load("hub://activeloop/gtzan-genre")

#temporary list for the input data
data = []

#list to append all the labels
Y = []

base_path = '../music_genre_classification/Data/genres_original'

#looping through all label directories
for label in tqdm(os.listdir(base_path)):
    file_path = base_path + '/' + label
    
    #looping through each file in the directory
    for pth in os.listdir(file_path):
        
        try:
            final_path = file_path + '/' + pth

            #loading original file
            audio, sr = librosa.load(final_path, duration = 28)
            
            #appending data to a list
            data.append(audio)
          

            #appending labels to the label list
            Y.append(label)
            
        except:
            print("Error in file", pth)
            pass
        
#converting list to a numpy array
X = np.stack(data)
# Out:
#  50%|█████     | 5/10 [00:02<00:04,  1.24it/s]C:\Users\ingvilcf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Error in file jazz.00054.wav
# 100%|██████████| 10/10 [00:09<00:00,  1.02it/s]

# %% [markdown]
# ## Split dataset

# %%
audio_train, audio_test, y_train, y_test = train_test_split(\
     X, Y, test_size=0.20, random_state=6)

audio_train, audio_val, y_train, y_val = train_test_split(\
     audio_train, y_train, test_size=0.30, random_state=6)

# %% [markdown]
# ## Augment data

# %%
add_noise = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.7),
])
pitch_shift = Compose([
    PitchShift(min_semitones=-4, max_semitones=12, p=0.5),
])

# %%
#setting melspec features
n_mels = 128
hop_length = 512
n_fft = 1024

def get_melspec(audio, sr = sr, n_fft = n_fft, hop_length = hop_length, n_mels = n_mels):
    #calculate the melspectogram of the provided audio wave
    S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
    
    return S

# %% [markdown]
# ## Augment training set

# %%
#temporary list for the input data
X_train = []

#list to append all the labels
Y_train = []

#looping through train data to create melspec and augment data
for i, dat in tqdm(enumerate(audio_train)):
        
    try:

        #adding noise to the file
        noisy_audio = add_noise(dat ,sr)
        #changing pitch of the audio
        pitch_audio = pitch_shift(dat, sr)

        #generate melspec for original and augmented files
        mel = get_melspec(dat)
        noise_mel = get_melspec(noisy_audio)
        pitch_mel = get_melspec(pitch_audio)

        #appending augmented data to original training data
        X_train.append(mel)
        Y_train.append(y_train[i])
        X_train.append(noise_mel)
        Y_train.append(y_train[i])
        X_train.append(pitch_mel)
        Y_train.append(y_train[i])


    except Exception as e:
        print("Error in file:", pth)
        print("Error:", e)
# Out:
# 0it [00:00, ?it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.02874756 -0.0322876
#  -0.03512573] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.0077381   0.00752281  0.00256896 ... -0.01472158 -0.03711864
#  -0.02043752] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.00222778 -0.04449463 -0.07247925 ...  0.20980835  0.10964966
#   0.00085449] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 2.4696998e-03 -4.3387324e-02 -7.1796298e-02 ...  2.0889723e-01
#   1.0843530e-01  8.7911205e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.00154784 -0.04439273 -0.07302418 ...  0.0166613   0.00739521
#   0.00359979] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 2it [00:02,  1.01s/it]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.04727173  0.02368164 -0.00256348 ... -0.03067017  0.00152588
#   0.01223755] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.
.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 546it [03:47,  1.45it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.05926514  0.06332397  0.03329468 ... -0.18356323 -0.11975098
#  -0.12011719] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.06414795 -0.00982666  0.08511353 ...  0.00915527  0.00942993
#   0.01150513] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.06295118 -0.01518768  0.09231919 ...  0.01481781  0.00704637
#   0.01264105] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.04098985  0.02286134  0.05233518 ...  0.00412654 -0.00080044
#   0.00165635] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 548it [03:48,  1.73it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.04309082  0.00143433 -0.02267456 ... -0.03677368 -0.03158569
#  -0.03042603] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.0181513   0.01762318 -0.02740004 ... -0.03401934 -0.0277958
#  -0.01102883] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.00747681  0.00671387  0.00643921 ... -0.0267334  -0.03237915
#  -0.0418396 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 550it [03:48,  2.59it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.0173645   0.01452637  0.02264404 ... -0.01327515  0.05987549
#   0.11938477] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.0208871   0.00318299  0.01468227 ... -0.00607725  0.0650107
#   0.12330393] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[0.14556885 0.09173584 0.03552246 ... 0.4527893  0.6854553  0.7267456 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[0.14670394 0.09097159 0.02901605 ... 0.4571722  0.6805138  0.7336341 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.13893208  0.1009299   0.03183924 ... -0.06061021 -0.12371237
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 552it [03:49,  2.72it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.04116821 -0.0506897  -0.07846069 ... -0.2617798  -0.24551392
#  -0.2965088 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.03953693 -0.04467963 -0.08764464 ... -0.2649603  -0.24052003
#  -0.29442796] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.05352783  0.15640259  0.14309692 ... -0.08172607 -0.05856323
#  -0.08215332] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.05360809  0.15682185  0.14316824 ... -0.08169312 -0.0567679
#  -0.08008969] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[ 0.0544163   0.138432    0.15499607 ... -0.0386048  -0.07713642
#  -0.10023531] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 554it [03:49,  2.84it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.07858276 -0.1638794  -0.11288452 ...  0.1663208   0.13668823
#   0.11276245] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.0844274  -0.16100071 -0.1139324  ...  0.15770443  0.1508189
#   0.10899365] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.09290583 -0.12550494  0.06559958 ... -0.0498495  -0.05271082
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 555it [03:50,  2.00it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.06268311 -0.07568359 -0.08706665 ...  0.5132141   0.4376831
#   0.35733032] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.06206602 -0.07571717 -0.08419742 ...  0.5156348   0.43803084
#   0.35859475] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.12237549 -0.04919434  0.04440308 ...  0.04443359  0.02359009
#   0.01901245] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.11580262 -0.0443217   0.03192413 ...  0.06879795  0.04158031
#   0.03625111] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 557it [03:51,  2.89it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.15115356 -0.23742676 -0.19647217 ... -0.01004028 -0.01223755
#  -0.01254272] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.1342508  -0.22003326 -0.16298923 ...  0.00044818  0.00444236
#   0.00910891] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 558it [03:52,  2.02it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.03820801 -0.06240845 -0.06326294 ... -0.05560303 -0.07467651
#  -0.08798218] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0.01397214 -0.07362919 -0.07014049 ... -0.06608081 -0.05515567
#  -0.09335633] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 559it [03:52,  2.41it/s]

# %% [markdown]
# ## Extract mel-spec features from test data

# %%
#temporary list for the input data
X_test = []

#list to append all the labels
Y_test = []

#looping through train data to create melspec and augment data
for i, dat in tqdm(enumerate(audio_test)):
        
    try:
        #generate melspec for original and augmented files
        mel = get_melspec(dat)
       
        #Appending test melspec to list
        X_test.append(mel)
        Y_test.append(y_test[i])
        

    except Exception as e:
        print("Error in file:", pth)
        print("Error:", e)
# Out:
# 0it [00:00, ?it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_17604\151441632.py:8: FutureWarning: Pass y=[-0
sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 200it [00:03, 65.63it/s]

# %%
#converting the test and train data to numpy array
X_train = np.stack(X_train)
X_test = np.stack(X_test)

# %%
encoder = LabelEncoder()
encoder.fit(Y_train)

Y_train = encoder.transform(Y_train).reshape([len(Y_train), 1])

encoder = LabelEncoder()
encoder.fit(Y_test)

Y_test = encoder.transform(Y_test).reshape([len(Y_test), 1])

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2],1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2],1)

# %% [markdown]
# # Model

# %%
#importing the keras modules
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, GRU
from keras.callbacks import Callback, EarlyStopping

#Initiating the model as Sequential
model = Sequential()

#Adding the CNN layers along with some drop outs and maxpooling
model.add(Conv2D(64, 2, activation = 'relu', input_shape = (X_train.shape[1:])))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, 2, activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(256, 2, activation = 'relu'))
model.add(MaxPooling2D(pool_size = (4,4)))
model.add(Dropout(0.1))

model.add(Conv2D(512, 2, activation = 'relu'))
model.add(MaxPooling2D(pool_size = (6,6)))
model.add(Dropout(0.1))

#flattening the data to be passed to a dense layer
model.add(Flatten())

#Adding the dense layers
model.add(Dense(2048, activation = 'relu'))
model.add(Dense(1024, activation = 'relu'))
model.add(Dense(256, activation = 'relu'))

#final output layer with 10 predictions to be made
model.add(Dense(10, activation = 'softmax'))

'''
Optimizer = Adam
Loss = Sparse Categorical CrossEntropy
'''
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_23 (Conv2D)          (None, 127, 1205, 64)     320
#
#  max_pooling2d_23 (MaxPoolin  (None, 63, 602, 64)      0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 63, 602, 64)       0
#
#  conv2d_24 (Conv2D)          (None, 62, 601, 128)      32896
#
#  max_pooling2d_24 (MaxPoolin  (None, 31, 300, 128)     0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 31, 300, 128)      0
#
#  conv2d_25 (Conv2D)          (None, 30, 299, 256)      131328
#
#  max_pooling2d_25 (MaxPoolin  (None, 7, 74, 256)       0
#  g2D)
#
#  dropout_23 (Dropout)        (None, 7, 74, 256)        0
#
#  conv2d_26 (Conv2D)          (None, 6, 73, 512)        524800
#
#  max_pooling2d_26 (MaxPoolin  (None, 1, 12, 512)       0
#  g2D)
#
#  dropout_24 (Dropout)        (None, 1, 12, 512)        0
#
#  flatten_4 (Flatten)         (None, 6144)              0
#
#  dense_16 (Dense)            (None, 2048)              12584960
#
#  dense_17 (Dense)            (None, 1024)              2098176
#
#  dense_18 (Dense)            (None, 256)               262400
#
#  dense_19 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 15,637,450
# Trainable params: 15,637,450
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test),epochs=50)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 300s 4s/step - loss: 4.5942 - accuracy: 0.1873 - val_loss: 1.9787 - val_accuracy: 0.3100
# Epoch 2/50
# 75/75 [==============================] - 369s 5s/step - loss: 1.8304 - accuracy: 0.3217 - val_loss: 1.8331 - val_accuracy: 0.3400
# Epoch 3/50
# 75/75 [==============================] - 297s 4s/step - loss: 1.6377 - accuracy: 0.3784 - val_loss: 1.7707 - val_accuracy: 0.3650
# Epoch 4/50
# 75/75 [==============================] - 292s 4s/step - loss: 1.4229 - accuracy: 0.4748 - val_loss: 1.6489 - val_accuracy: 0.4600
# Epoch 5/50
# 75/75 [==============================] - 291s 4s/step - loss: 1.3465 - accuracy: 0.5574 - val_loss: 1.6455 - val_accuracy: 0.4450
# Epoch 6/50
# 75/75 [==============================] - 291s 4s/step - loss: 1.1116 - accuracy: 0.6362 - val_loss: 2.0317 - val_accuracy: 0.4300
# Epoch 7/50
# 75/75 [==============================] - 291s 4s/step - loss: 0.8216 - accuracy: 0.7213 - val_loss: 2.0866 - val_accuracy: 0.4700
# Epoch 8/50
# 75/75 [==============================] - 293s 4s/step - loss: 0.7995 - accuracy: 0.7413 - val_loss: 1.7226 - val_accuracy: 0.4850
# Epoch 9/50
# 75/75 [==============================] - 290s 4s/step - loss: 0.5536 - accuracy: 0.8198 - val_loss: 2.7383 - val_accuracy: 0.4250
# Epoch 10/50
# 75/75 [==============================] - 288s 4s/step - loss: 0.4637 - accuracy: 0.8678 - val_loss: 2.5663 - val_accuracy: 0.4600
# Epoch 11/50
# 75/75 [==============================] - 290s 4s/step - loss: 0.3926 - accuracy: 0.8773 - val_loss: 2.7470 - val_accuracy: 0.4700
# Epoch 12/50
# 75/75 [==============================] - 290s 4s/step - loss: 0.2604 - accuracy: 0.9299 - val_loss: 2.9147 - val_accuracy: 0.4200
# Epoch 13/50
# 75/75 [==============================] - 290s 4s/step - loss: 0.2434 - accuracy: 0.9324 - val_loss: 4.7637 - val_accuracy: 0.3750
# Epoch 14/50
# 75/75 [==============================] - 288s 4s/step - loss: 0.3089 - accuracy: 0.9136 - val_loss: 3.4028 - val_accuracy: 0.3950
# Epoch 15/50
# 75/75 [==============================] - 287s 4s/step - loss: 0.1955 - accuracy: 0.9491 - val_loss: 3.0553 - val_accuracy: 0.4550
# Epoch 16/50
# 75/75 [==============================] - 289s 4s/step - loss: 0.1316 - accuracy: 0.9679 - val_loss: 4.1298 - val_accuracy: 0.4100
# Epoch 17/50
# 75/75 [==============================] - 301s 4s/step - loss: 0.1656 - accuracy: 0.9574 - val_loss: 3.7322 - val_accuracy: 0.4700
# Epoch 18/50
# 75/75 [==============================] - 69982s 946s/step - loss: 0.1410 - accuracy: 0.9645 - val_loss: 4.2095 - val_accuracy: 0.4150
# Epoch 19/50
# 75/75 [==============================] - 290s 4s/step - loss: 0.1410 - accuracy: 0.9654 - val_loss: 4.3460 - val_accuracy: 0.3950
# Epoch 20/50
# 75/75 [==============================] - 288s 4s/step - loss: 0.1884 - accuracy: 0.9495 - val_loss: 3.8431 - val_accuracy: 0.4250
# Epoch 21/50
# 75/75 [==============================] - 288s 4s/step - loss: 0.1894 - accuracy: 0.9470 - val_loss: 4.4383 - val_accuracy: 0.4100
# Epoch 22/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.1393 - accuracy: 0.9641 - val_loss: 3.9455 - val_accuracy: 0.4550
# Epoch 23/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.1701 - accuracy: 0.9595 - val_loss: 5.7352 - val_accuracy: 0.4200
# Epoch 24/50
# 75/75 [==============================] - 288s 4s/step - loss: 0.1743 - accuracy: 0.9641 - val_loss: 3.5181 - val_accuracy: 0.4200
# Epoch 25/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.1023 - accuracy: 0.9766 - val_loss: 3.6969 - val_accuracy: 0.4650
# Epoch 26/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.0717 - accuracy: 0.9808 - val_loss: 3.8603 - val_accuracy: 0.4400
# Epoch 27/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.0332 - accuracy: 0.9908 - val_loss: 4.3438 - val_accuracy: 0.4700
# Epoch 28/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.2131 - accuracy: 0.9604 - val_loss: 3.5719 - val_accuracy: 0.4400
# Epoch 29/50
# 75/75 [==============================] - 287s 4s/step - loss: 0.1052 - accuracy: 0.9750 - val_loss: 3.6018 - val_accuracy: 0.4200
# Epoch 30/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.0571 - accuracy: 0.9833 - val_loss: 3.4560 - val_accuracy: 0.4300
# Epoch 31/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.0313 - accuracy: 0.9921 - val_loss: 3.9689 - val_accuracy: 0.4200
# Epoch 32/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.0398 - accuracy: 0.9892 - val_loss: 3.7946 - val_accuracy: 0.4500
# Epoch 33/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.0783 - accuracy: 0.9796 - val_loss: 4.6689 - val_accuracy: 0.4000
# Epoch 34/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.1574 - accuracy: 0.9583 - val_loss: 3.4817 - val_accuracy: 0.4600
# Epoch 35/50
# 75/75 [==============================] - 287s 4s/step - loss: 0.0748 - accuracy: 0.9779 - val_loss: 4.7214 - val_accuracy: 0.4250
# Epoch 36/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.0940 - accuracy: 0.9800 - val_loss: 4.5085 - val_accuracy: 0.3500
# Epoch 37/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.0541 - accuracy: 0.9887 - val_loss: 5.1506 - val_accuracy: 0.3850
# Epoch 38/50
# 75/75 [==============================] - 289s 4s/step - loss: 0.1104 - accuracy: 0.9733 - val_loss: 4.5714 - val_accuracy: 0.3850
# Epoch 39/50
# 75/75 [==============================] - 296s 4s/step - loss: 0.0789 - accuracy: 0.9812 - val_loss: 3.7192 - val_accuracy: 0.4600
# Epoch 40/50
# 75/75 [==============================] - 286s 4s/step - loss: 0.0600 - accuracy: 0.9816 - val_loss: 4.4742 - val_accuracy: 0.4450
# Epoch 41/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.0320 - accuracy: 0.9887 - val_loss: 4.4575 - val_accuracy: 0.4700
# Epoch 42/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.0243 - accuracy: 0.9946 - val_loss: 4.5610 - val_accuracy: 0.4550
# Epoch 43/50
# 75/75 [==============================] - 290s 4s/step - loss: 0.0785 - accuracy: 0.9821 - val_loss: 5.0431 - val_accuracy: 0.4150
# Epoch 44/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.2293 - accuracy: 0.9524 - val_loss: 4.6239 - val_accuracy: 0.4250
# Epoch 45/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.0281 - accuracy: 0.9929 - val_loss: 4.0822 - val_accuracy: 0.4550
# Epoch 46/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.0160 - accuracy: 0.9962 - val_loss: 4.3246 - val_accuracy: 0.4400
# Epoch 47/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.0588 - accuracy: 0.9837 - val_loss: 3.5936 - val_accuracy: 0.4200
# Epoch 48/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.1210 - accuracy: 0.9762 - val_loss: 3.7947 - val_accuracy: 0.4250
# Epoch 49/50
# 75/75 [==============================] - 285s 4s/step - loss: 0.0364 - accuracy: 0.9908 - val_loss: 4.8242 - val_accuracy: 0.4600
# Epoch 50/50
# 75/75 [==============================] - 287s 4s/step - loss: 0.0291 - accuracy: 0.9912 - val_loss: 3.7992 - val_accuracy: 0.4650

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
print()

# %%
# Save the model
model.save('cnn_1.h5')
