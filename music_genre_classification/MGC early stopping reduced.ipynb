# %% [markdown]
# # Music Genre Classification

# %%
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
from tqdm import tqdm
import os

import librosa.display
import deeplake

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Load dataset

# %%
#ds = deeplake.load("hub://activeloop/gtzan-genre")

#temporary list for the input data
data = []

#list to append all the labels
Y = []

base_path = '../music_genre_classification/Data/genres_original'

#looping through all label directories
for label in tqdm(os.listdir(base_path)):
    file_path = base_path + '/' + label
    
    #looping through each file in the directory
    for pth in os.listdir(file_path):
        
        try:
            final_path = file_path + '/' + pth

            #loading original file
            audio, sr = librosa.load(final_path, duration = 28)
            
            #appending data to a list
            data.append(audio)
          

            #appending labels to the label list
            Y.append(label)
            
        except:
            print("Error in file", pth)
            pass
        
#converting list to a numpy array
X = np.stack(data)
# Out:
#  50%|█████     | 5/10 [00:02<00:02,  2.29it/s]C:\Users\ingvilcf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
#  60%|██████    | 6/10 [00:02<00:01,  2.33it/s]
# Error in file jazz.00054.wav
# 100%|██████████| 10/10 [00:03<00:00,  2.54it/s]

# %% [markdown]
# ## Split dataset

# %%
audio_train, audio_test, y_train, y_test = train_test_split(\
     X, Y, test_size=0.20, random_state=6)

# %% [markdown]
# ## Augment data

# %%
add_noise = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.7),
])
pitch_shift = Compose([
    PitchShift(min_semitones=-4, max_semitones=12, p=0.5),
])

# %%
#setting melspec features
n_mels = 128
hop_length = 512
n_fft = 1024

def get_melspec(audio, sr = sr, n_fft = n_fft, hop_length = hop_length, n_mels = n_mels):
    #calculate the melspectogram of the provided audio wave
    S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
    
    return S

# %% [markdown]
# ## Augment training set

# %%
#temporary list for the input data
X_train = []

#list to append all the labels
Y_train = []

#looping through train data to create melspec and augment data
for i, dat in tqdm(enumerate(audio_train)):
        
    try:

        #adding noise to the file
        noisy_audio = add_noise(dat ,sr)
        #changing pitch of the audio
        pitch_audio = pitch_shift(dat, sr)

        #generate melspec for original and augmented files
        mel = get_melspec(dat)
        noise_mel = get_melspec(noisy_audio)
        pitch_mel = get_melspec(pitch_audio)

        #appending augmented data to original training data
        X_train.append(mel)
        Y_train.append(y_train[i])
        X_train.append(noise_mel)
        Y_train.append(y_train[i])
        X_train.append(pitch_mel)
        Y_train.append(y_train[i])


    except Exception as e:
        print("Error in file:", pth)
        print("Error:", e)
# Out:
# 0it [00:00, ?it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.35791016 0.3979187  0.32870483 ... 0.19400024 0.21530151 0.21347046] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.35818538 0.39922795 0.32494196 ... 0.1996894  0.20923947 0.2022023 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.3441356  0.4139675  0.33583298 ... 0.0148829  0.00911065 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 1it [00:01,  1.29s/it]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.3352661  0.1633606  0.08322144 ... 0.00302124 0.02661133 0.04690552] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.33899927 0.15582599 0.07485679 ... 0.01017273 0.01563898 0.04733302] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[ 0.32651806  0.2059864   0.06124289 ...  0.01461308  0.00498826
#  -0.00052267] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 2it [00:01,  1.07it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.06436157 -0.06713867 -0.0713501  ...  0.0022583   0.00018311
#  -0.00210571] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.06844813 -0.06119664 -0.07392286 ...  0.0127528  -0.00895464
#   0.00064832] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.00817871 0.00778198 0.0067749  ... 0.01654053 0.0105896  0.0123291 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[ 0.
as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.04021434  0.03985367  0.05892227 ... -0.06826187 -0.04956225
#   0.00802018] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 786it [05:42,  2.01it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.5245056  -0.81640625 -0.5826111  ...  0.0496521   0.05169678
#   0.00482178] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.5204423  -0.8293158  -0.59085083 ...  0.06296726  0.05127801
#  -0.01579879] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.02557373 0.04382324 0.03601074 ... 0.04547119 0.02261353 0.01437378] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.02759429 0.03814781 0.03667944 ... 0.04091213 0.02536892 0.01927562] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 788it [05:42,  2.84it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[ 0.10665894  0.16796875  0.13589478 ... -0.15527344 -0.21212769
#  -0.22445679] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[ 0.11717906  0.16744041  0.13458385 ... -0.16766612 -0.20135207
#  -0.23629224] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.10176232 0.14975625 0.13518941 ... 0.07559361 0.06604193 0.0619724 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 789it [05:43,  2.23it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[ 0.401886    0.31951904  0.34765625 ...  0.13256836 -0.06036377
#   0.03277588] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.14013672 -0.14840698 -0.06219482 ... -0.08850098 -0.14932251
#  -0.16305542] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.12050235 -0.15057985 -0.06858152 ... -0.09192172 -0.15666385
#  -0.15226594] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 791it [05:43,  3.23it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.06140137 -0.03152466 -0.00521851 ...  0.05651855  0.04925537
#   0.02593994] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.05685012 -0.04086639 -0.0061045  ...  0.01277326  0.02081473
#   0.03356008] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 792it [05:44,  2.74it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.08514404 -0.08752441 -0.09707642 ... -0.34503174 -0.68756104
#  -0.31704712] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.08589693 -0.08975527 -0.09635339 ... -0.3424849  -0.68584085
#  -0.3137779 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.06421664 -0.10252945 -0.10539784 ... -0.02315381  0.0626625
#   0.12361477] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 793it [05:45,  1.95it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.21340942 -0.14624023 -0.13067627 ...  0.23782349  0.27331543
#   0.28805542] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.21090953 -0.14025679 -0.12600408 ...  0.23143269  0.28177765
#   0.28306025] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[ 0.06192017  0.01989746 -0.03140259 ...  0.04510498 -0.00106812
#  -0.01190186] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[ 0.05230715 -0.00854489  0.06789379 ...  0.00769674 -0.00690344
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 795it [05:46,  2.00it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.02493286  0.00021362  0.10403442 ... -0.02288818  0.03179932
#   0.07211304] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0.10757446 -0.1585083  -0.12939453 ... -0.09362793 -0.08807373
#  -0.11138916] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[ 0.07824707  0.07504272  0.07333374 ... -0.00439453  0.01382446
#   0.02102661] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[ 0.07788077  0.08007549  0.07191777 ... -0.00592951  0.01536761
#   0.02679022] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.06527326 0.08197502 0.06589    ... 0.01872229 0.01099902 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 798it [05:47,  2.39it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.10076904 0.15240479 0.12155151 ... 0.08981323 0.09414673 0.10461426] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[0.08080454 0.13942882 0.1150781  ... 0.07588957 0.08244491 0.09223669] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 799it [05:47,  2.30it/s]

# %% [markdown]
# ## Extract mel-spec features from test data

# %%
#temporary list for the input data
X_test = []

#list to append all the labels
Y_test = []

#looping through train data to create melspec and augment data
for i, dat in tqdm(enumerate(audio_test)):
        
    try:
        #generate melspec for original and augmented files
        mel = get_melspec(dat)
       
        #Appending test melspec to list
        X_test.append(mel)
        Y_test.append(y_test[i])
        

    except Exception as e:
        print("Error in file:", pth)
        print("Error:", e)
# Out:
# 0it [00:00, ?it/s]C:\Users\ingvilcf\AppData\Local\Temp\ipykernel_21096\151441632.py:8: FutureWarning: Pass y=[-0
as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   S = librosa.feature.melspectrogram(audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
# 200it [00:02, 66.68it/s]

# %%
#converting the test and train data to numpy array
X_train = np.stack(X_train)
X_test = np.stack(X_test)

# %%
# Encode target values to numbers
encoder = LabelEncoder()
encoder.fit(Y_train)

Y_train = encoder.transform(Y_train).reshape([len(Y_train), 1])

encoder = LabelEncoder()
encoder.fit(Y_test)

Y_test = encoder.transform(Y_test).reshape([len(Y_test), 1])

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2],1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2],1)

# %% [markdown]
# # Model

# %%
#importing the keras modules
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, GRU
from keras.callbacks import Callback, EarlyStopping

#Initiating the model as Sequential
model = Sequential()

#Adding the CNN layers along with some drop outs and maxpooling
model.add(Conv2D(64, 2, activation = 'relu', input_shape = (X_train.shape[1:])))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, 2, activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(256, 2, activation = 'relu'))
model.add(MaxPooling2D(pool_size = (4,4)))
model.add(Dropout(0.3))

model.add(Conv2D(512, 2, activation = 'relu'))
model.add(MaxPooling2D(pool_size = (6,6)))
model.add(Dropout(0.3))

#flattening the data to be passed to a dense layer
model.add(Flatten())

#Adding the dense layers
model.add(Dense(2048, activation = 'relu'))
model.add(Dense(1024, activation = 'relu'))
model.add(Dense(256, activation = 'relu'))

#final output layer with 10 predictions to be made
model.add(Dense(10, activation = 'softmax'))

'''
Optimizer = Adam
Loss = Sparse Categorical CrossEntropy
'''
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Early stopping if no improvement for 2 iterations
callback = EarlyStopping(monitor='loss', patience=2)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 127, 1205, 64)     320
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 602, 64)      0
#  2D)
#
#  dropout_4 (Dropout)         (None, 63, 602, 64)       0
#
#  conv2d_5 (Conv2D)           (None, 62, 601, 128)      32896
#
#  max_pooling2d_5 (MaxPooling  (None, 31, 300, 128)     0
#  2D)
#
#  dropout_5 (Dropout)         (None, 31, 300, 128)      0
#
#  conv2d_6 (Conv2D)           (None, 30, 299, 256)      131328
#
#  max_pooling2d_6 (MaxPooling  (None, 7, 74, 256)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 7, 74, 256)        0
#
#  conv2d_7 (Conv2D)           (None, 6, 73, 512)        524800
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 12, 512)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 1, 12, 512)        0
#
#  flatten_1 (Flatten)         (None, 6144)              0
#
#  dense_4 (Dense)             (None, 2048)              12584960
#
#  dense_5 (Dense)             (None, 1024)              2098176
#
#  dense_6 (Dense)             (None, 256)               262400
#
#  dense_7 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 15,637,450
# Trainable params: 15,637,450
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test),callbacks=[callback],epochs=20)
print(len(history.history['loss']))
# Out:
# Epoch 1/20
# 10/75 [===>..........................] - ETA: 4:47 - loss: 26.4389 - accuracy: 0.1125

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
print()

# %%
plt.plot(history.history['error'])
plt.plot(history.history['val_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [47], line 1
# ----> 1 plt.plot(history.history['error'])
#       2 plt.plot(history.history['val_error'])
#       3 plt.title('model accuracy')
#
# KeyError: 'error'

# %%
# Save the model
model.save('cnn_1.h5')
